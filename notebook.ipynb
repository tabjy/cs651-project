# %% [markdown]
# # PySpark Installtion

# %%
# !apt-get update -qq > /dev/null
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://archive.apache.org/dist/spark/spark-3.0.0/spark-3.0.0-bin-hadoop3.2.tgz
# !tar xf spark-3.0.0-bin-hadoop3.2.tgz
# !pip install -q findspark

# %% [markdown]
# # Mount Google Drive

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ### Create spark sessionn

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "spark-3.0.0-bin-hadoop3.2"

import findspark
findspark.init()

from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession

spark_conf = SparkConf()\
  .setAppName("YourTest")\
  .setMaster("local[*]")

sc = SparkContext.getOrCreate(spark_conf)

# %%
def create_spark_session():
    """Create Spark Session
    
    Return (obj): Spark configured session instance
    """
    spark = SparkSession \
        .builder \
        .config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:2.7.0") \
        .getOrCreate()
    return spark

# %%
from pyspark.sql.functions import *

# %%
spark = create_spark_session()

# %%
main_data_link = "gs://cs-651-data-bucket"

# %%
df_blocks = spark.read.parquet(main_data_link + "/dataset-blk01000-01999/blocks")

# %%
# df_blocks.show(10)

# %%
df_blocks.select('file').distinct().collect()
# Out:
# [Row(file='blk01397.dat'),
#  Row(file='blk01735.dat'),
#  Row(file='blk01931.dat'),
#  Row(file='blk01010.dat'),
#  Row(file='blk01894.dat'),
#  Row(file='blk01608.dat'),
#  Row(file='blk01306.dat'),
#  Row(file='blk01347.dat'),
#  Row(file='blk01394.dat'),
#  Row(file='blk01823.dat'),
#  Row(file='blk01100.dat'),
#  Row(file='blk01103.dat'),
#  Row(file='blk01054.dat'),
#  Row(file='blk01363.dat'),
#  Row(file='blk01557.dat'),
#  Row(file='blk01797.dat'),
#  Row(file='blk01804.dat'),
#  Row(file='blk01358.dat'),
#  Row(file='blk01091.dat'),
#  Row(file='blk01598.dat'),
#  Row(file='blk01303.dat'),
#  Row(file='blk01870.dat'),
#  Row(file='blk01793.dat'),
#  Row(file='blk01224.dat'),
#  Row(file='blk01142.dat'),
#  Row(file='blk01843.dat'),
#  Row(file='blk01893.dat'),
#  Row(file='blk01541.dat'),
#  Row(file='blk01139.dat'),
#  Row(file='blk01119.dat'),
#  Row(file='blk01302.dat'),
#  Row(file='blk01430.dat'),
#  Row(file='blk01036.dat'),
#  Row(file='blk01391.dat'),
#  Row(file='blk01461.dat'),
#  Row(file='blk01140.dat'),
#  Row(file='blk01897.dat'),
#  Row(file='blk01439.dat'),
#  Row(file='blk01067.dat'),
#  Row(file='blk01484.dat'),
#  Row(file='blk01357.dat'),
#  Row(file='blk01503.dat'),
#  Row(file='blk01188.dat'),
#  Row(file='blk01383.dat'),
#  Row(file='blk01695.dat'),
#  Row(file='blk01368.dat'),
#  Row(file='blk01502.dat'),
#  Row(file='blk01364.dat'),
#  Row(file='blk01388.dat'),
#  Row(file='blk01204.dat'),
#  Row(file='blk01753.dat'),
#  Row(file='blk01722.dat'),
#  Row(file='blk01353.dat'),
#  Row(file='blk01483.dat'),
#  Row(file='blk01273.dat'),
#  Row(file='blk01112.dat'),
#  Row(file='blk01105.dat'),
#  Row(file='blk01395.dat'),
#  Row(file='blk01706.dat'),
#  Row(file='blk01316.dat'),
#  Row(file='blk01528.dat'),
#  Row(file='blk01681.dat'),
#  Row(file='blk01218.dat'),
#  Row(file='blk01333.dat'),
#  Row(file='blk01179.dat'),
#  Row(file='blk01566.dat'),
#  Row(file='blk01582.dat'),
#  Row(file='blk01667.dat'),
#  Row(file='blk01679.dat'),
#  Row(file='blk01618.dat'),
#  Row(file='blk01988.dat'),
#  Row(file='blk01163.dat'),
#  Row(file='blk01837.dat'),
#  Row(file='blk01678.dat'),
#  Row(file='blk01166.dat'),
#  Row(file='blk01581.dat'),
#  Row(file='blk01560.dat'),
#  Row(file='blk01697.dat'),
#  Row(file='blk01727.dat'),
#  Row(file='blk01327.dat'),
#  Row(file='blk01274.dat'),
#  Row(file='blk01240.dat'),
#  Row(file='blk01292.dat'),
#  Row(file='blk01538.dat'),
#  Row(file='blk01366.dat'),
#  Row(file='blk01123.dat'),
#  Row(file='blk01975.dat'),
#  Row(file='blk01732.dat'),
#  Row(file='blk01774.dat'),
#  Row(file='blk01128.dat'),
#  Row(file='blk01296.dat'),
#  Row(file='blk01748.dat'),
#  Row(file='blk01008.dat'),
#  Row(file='blk01249.dat'),
#  Row(file='blk01936.dat'),
#  Row(file='blk01096.dat'),
#  Row(file='blk01334.dat'),
#  Row(file='blk01109.dat'),
#  Row(file='blk01940.dat'),
#  Row(file='blk01663.dat'),
#  Row(file='blk01590.dat'),
#  Row(file='blk01378.dat'),
#  Row(file='blk01472.dat'),
#  Row(file='blk01170.dat'),
#  Row(file='blk01526.dat'),
#  Row(file='blk01729.dat'),
#  Row(file='blk01354.dat'),
#  Row(file='blk01317.dat'),
#  Row(file='blk01331.dat'),
#  Row(file='blk01738.dat'),
#  Row(file='blk01065.dat'),
#  Row(file='blk01613.dat'),
#  Row(file='blk01745.dat'),
#  Row(file='blk01034.dat'),
#  Row(file='blk01442.dat'),
#  Row(file='blk01759.dat'),
#  Row(file='blk01000.dat'),
#  Row(file='blk01493.dat'),
#  Row(file='blk01917.dat'),
#  Row(file='blk01669.dat'),
#  Row(file='blk01775.dat'),
#  Row(file='blk01744.dat'),
#  Row(file='blk01615.dat'),
#  Row(file='blk01807.dat'),
#  Row(file='blk01675.dat'),
#  Row(file='blk01885.dat'),
#  Row(file='blk01818.dat'),
#  Row(file='blk01896.dat'),
#  Row(file='blk01144.dat'),
#  Row(file='blk01958.dat'),
#  Row(file='blk01137.dat'),
#  Row(file='blk01833.dat'),
#  Row(file='blk01377.dat'),
#  Row(file='blk01776.dat'),
#  Row(file='blk01954.dat'),
#  Row(file='blk01659.dat'),
#  Row(file='blk01141.dat'),
#  Row(file='blk01408.dat'),
#  Row(file='blk01806.dat'),
#  Row(file='blk01933.dat'),
#  Row(file='blk01880.dat'),
#  Row(file='blk01884.dat'),
#  Row(file='blk01670.dat'),
#  Row(file='blk01777.dat'),
#  Row(file='blk01132.dat'),
#  Row(file='blk01073.dat'),
#  Row(file='blk01454.dat'),
#  Row(file='blk01969.dat'),
#  Row(file='blk01616.dat'),
#  Row(file='blk01282.dat'),
#  Row(file='blk01404.dat'),
#  Row(file='blk01660.dat'),
#  Row(file='blk01612.dat'),
#  Row(file='blk01769.dat'),
#  Row(file='blk01746.dat'),
#  Row(file='blk01539.dat'),
#  Row(file='blk01499.dat'),
#  Row(file='blk01056.dat'),
#  Row(file='blk01595.dat'),
#  Row(file='blk01369.dat'),
#  Row(file='blk01992.dat'),
#  Row(file='blk01786.dat'),
#  Row(file='blk01906.dat'),
#  Row(file='blk01198.dat'),
#  Row(file='blk01859.dat'),
#  Row(file='blk01805.dat'),
#  Row(file='blk01450.dat'),
#  Row(file='blk01148.dat'),
#  Row(file='blk01731.dat'),
#  Row(file='blk01283.dat'),
#  Row(file='blk01522.dat'),
#  Row(file='blk01656.dat'),
#  Row(file='blk01668.dat'),
#  Row(file='blk01342.dat'),
#  Row(file='blk01949.dat'),
#  Row(file='blk01883.dat'),
#  Row(file='blk01070.dat'),
#  Row(file='blk01015.dat'),
#  Row(file='blk01773.dat'),
#  Row(file='blk01778.dat'),
#  Row(file='blk01314.dat'),
#  Row(file='blk01225.dat'),
#  Row(file='blk01190.dat'),
#  Row(file='blk01041.dat'),
#  Row(file='blk01343.dat'),
#  Row(file='blk01705.dat'),
#  Row(file='blk01047.dat'),
#  Row(file='blk01287.dat'),
#  Row(file='blk01904.dat'),
#  Row(file='blk01469.dat'),
#  Row(file='blk01311.dat'),
#  Row(file='blk01648.dat'),
#  Row(file='blk01260.dat'),
#  Row(file='blk01825.dat'),
#  Row(file='blk01645.dat'),
#  Row(file='blk01238.dat'),
#  Row(file='blk01895.dat'),
#  Row(file='blk01559.dat'),
#  Row(file='blk01471.dat'),
#  Row(file='blk01387.dat'),
#  Row(file='blk01882.dat'),
#  Row(file='blk01795.dat'),
#  Row(file='blk01231.dat'),
#  Row(file='blk01997.dat'),
#  Row(file='blk01696.dat'),
#  Row(file='blk01849.dat'),
#  Row(file='blk01664.dat'),
#  Row(file='blk01489.dat'),
#  Row(file='blk01464.dat'),
#  Row(file='blk01811.dat'),
#  Row(file='blk01816.dat'),
#  Row(file='blk01596.dat'),
#  Row(file='blk01780.dat'),
#  Row(file='blk01860.dat'),
#  Row(file='blk01412.dat'),
#  Row(file='blk01576.dat'),
#  Row(file='blk01752.dat'),
#  Row(file='blk01510.dat'),
#  Row(file='blk01247.dat'),
#  Row(file='blk01235.dat'),
#  Row(file='blk01719.dat'),
#  Row(file='blk01348.dat'),
#  Row(file='blk01871.dat'),
#  Row(file='blk01318.dat'),
#  Row(file='blk01386.dat'),
#  Row(file='blk01661.dat'),
#  Row(file='blk01796.dat'),
#  Row(file='blk01520.dat'),
#  Row(file='blk01017.dat'),
#  Row(file='blk01513.dat'),
#  Row(file='blk01802.dat'),
#  Row(file='blk01653.dat'),
#  Row(file='blk01800.dat'),
#  Row(file='blk01480.dat'),
#  Row(file='blk01219.dat'),
#  Row(file='blk01946.dat'),
#  Row(file='blk01890.dat'),
#  Row(file='blk01272.dat'),
#  Row(file='blk01117.dat'),
#  Row(file='blk01966.dat'),
#  Row(file='blk01254.dat'),
#  Row(file='blk01173.dat'),
#  Row(file='blk01474.dat'),
#  Row(file='blk01715.dat'),
#  Row(file='blk01672.dat'),
#  Row(file='blk01389.dat'),
#  Row(file='blk01789.dat'),
#  Row(file='blk01519.dat'),
#  Row(file='blk01055.dat'),
#  Row(file='blk01924.dat'),
#  Row(file='blk01635.dat'),
#  Row(file='blk01987.dat'),
#  Row(file='blk01552.dat'),
#  Row(file='blk01373.dat'),
#  Row(file='blk01918.dat'),
#  Row(file='blk01009.dat'),
#  Row(file='blk01617.dat'),
#  Row(file='blk01049.dat'),
#  Row(file='blk01401.dat'),
#  Row(file='blk01435.dat'),
#  Row(file='blk01079.dat'),
#  Row(file='blk01026.dat'),
#  Row(file='blk01053.dat'),
#  Row(file='blk01662.dat'),
#  Row(file='blk01761.dat'),
#  Row(file='blk01297.dat'),
#  Row(file='blk01844.dat'),
#  Row(file='blk01102.dat'),
#  Row(file='blk01641.dat'),
#  Row(file='blk01409.dat'),
#  Row(file='blk01556.dat'),
#  Row(file='blk01782.dat'),
#  Row(file='blk01930.dat'),
#  Row(file='blk01001.dat'),
#  Row(file='blk01400.dat'),
#  Row(file='blk01610.dat'),
#  Row(file='blk01639.dat'),
#  Row(file='blk01646.dat'),
#  Row(file='blk01737.dat'),
#  Row(file='blk01739.dat'),
#  Row(file='blk01138.dat'),
#  Row(file='blk01591.dat'),
#  Row(file='blk01381.dat'),
#  Row(file='blk01767.dat'),
#  Row(file='blk01051.dat'),
#  Row(file='blk01487.dat'),
#  Row(file='blk01537.dat'),
#  Row(file='blk01781.dat'),
#  Row(file='blk01217.dat'),
#  Row(file='blk01632.dat'),
#  Row(file='blk01341.dat'),
#  Row(file='blk01817.dat'),
#  Row(file='blk01991.dat'),
#  Row(file='blk01820.dat'),
#  Row(file='blk01810.dat'),
#  Row(file='blk01702.dat'),
#  Row(file='blk01485.dat'),
#  Row(file='blk01346.dat'),
#  Row(file='blk01511.dat'),
#  Row(file='blk01418.dat'),
#  Row(file='blk01468.dat'),
#  Row(file='blk01478.dat'),
#  Row(file='blk01638.dat'),
#  Row(file='blk01221.dat'),
#  Row(file='blk01365.dat'),
#  Row(file='blk01390.dat'),
#  Row(file='blk01174.dat'),
#  Row(file='blk01202.dat'),
#  Row(file='blk01626.dat'),
#  Row(file='blk01514.dat'),
#  Row(file='blk01985.dat'),
#  Row(file='blk01462.dat'),
#  Row(file='blk01798.dat'),
#  Row(file='blk01644.dat'),
#  Row(file='blk01458.dat'),
#  Row(file='blk01172.dat'),
#  Row(file='blk01589.dat'),
#  Row(file='blk01332.dat'),
#  Row(file='blk01093.dat'),
#  Row(file='blk01996.dat'),
#  Row(file='blk01456.dat'),
#  Row(file='blk01193.dat'),
#  Row(file='blk01956.dat'),
#  Row(file='blk01426.dat'),
#  Row(file='blk01081.dat'),
#  Row(file='blk01136.dat'),
#  Row(file='blk01863.dat'),
#  Row(file='blk01326.dat'),
#  Row(file='blk01157.dat'),
#  Row(file='blk01063.dat'),
#  Row(file='blk01604.dat'),
#  Row(file='blk01959.dat'),
#  Row(file='blk01319.dat'),
#  Row(file='blk01700.dat'),
#  Row(file='blk01851.dat'),
#  Row(file='blk01898.dat'),
#  Row(file='blk01320.dat'),
#  Row(file='blk01255.dat'),
#  Row(file='blk01057.dat'),
#  Row(file='blk01082.dat'),
#  Row(file='blk01886.dat'),
#  Row(file='blk01990.dat'),
#  Row(file='blk01488.dat'),
#  Row(file='blk01950.dat'),
#  Row(file='blk01078.dat'),
#  Row(file='blk01459.dat'),
#  Row(file='blk01650.dat'),
#  Row(file='blk01267.dat'),
#  Row(file='blk01476.dat'),
#  Row(file='blk01547.dat'),
#  Row(file='blk01411.dat'),
#  Row(file='blk01115.dat'),
#  Row(file='blk01907.dat'),
#  Row(file='blk01926.dat'),
#  Row(file='blk01280.dat'),
#  Row(file='blk01916.dat'),
#  Row(file='blk01422.dat'),
#  Row(file='blk01821.dat'),
#  Row(file='blk01873.dat'),
#  Row(file='blk01889.dat'),
#  Row(file='blk01062.dat'),
#  Row(file='blk01999.dat'),
#  Row(file='blk01847.dat'),
#  Row(file='blk01585.dat'),
#  Row(file='blk01941.dat'),
#  Row(file='blk01814.dat'),
#  Row(file='blk01553.dat'),
#  Row(file='blk01671.dat'),
#  Row(file='blk01694.dat'),
#  Row(file='blk01261.dat'),
#  Row(file='blk01879.dat'),
#  Row(file='blk01960.dat'),
#  Row(file='blk01437.dat'),
#  Row(file='blk01500.dat'),
#  Row(file='blk01799.dat'),
#  Row(file='blk01290.dat'),
#  Row(file='blk01337.dat'),
#  Row(file='blk01901.dat'),
#  Row(file='blk01475.dat'),
#  Row(file='blk01300.dat'),
#  Row(file='blk01171.dat'),
#  Row(file='blk01963.dat'),
#  Row(file='blk01114.dat'),
#  Row(file='blk01460.dat'),
#  Row(file='blk01587.dat'),
#  Row(file='blk01720.dat'),
#  Row(file='blk01947.dat'),
#  Row(file='blk01452.dat'),
#  Row(file='blk01900.dat'),
#  Row(file='blk01684.dat'),
#  Row(file='blk01338.dat'),
#  Row(file='blk01470.dat'),
#  Row(file='blk01113.dat'),
#  Row(file='blk01068.dat'),
#  Row(file='blk01162.dat'),
#  Row(file='blk01271.dat'),
#  Row(file='blk01630.dat'),
#  Row(file='blk01515.dat'),
#  Row(file='blk01550.dat'),
#  Row(file='blk01676.dat'),
#  Row(file='blk01710.dat'),
#  Row(file='blk01349.dat'),
#  Row(file='blk01309.dat'),
#  Row(file='blk01498.dat'),
#  Row(file='blk01201.dat'),
#  Row(file='blk01064.dat'),
#  Row(file='blk01976.dat'),
#  Row(file='blk01345.dat'),
#  Row(file='blk01088.dat'),
#  Row(file='blk01445.dat'),
#  Row(file='blk01424.dat'),
#  Row(file='blk01160.dat'),
#  Row(file='blk01074.dat'),
#  Row(file='blk01677.dat'),
#  Row(file='blk01147.dat'),
#  Row(file='blk01546.dat'),
#  Row(file='blk01891.dat'),
#  Row(file='blk01749.dat'),
#  Row(file='blk01531.dat'),
#  Row(file='blk01544.dat'),
#  Row(file='blk01233.dat'),
#  Row(file='blk01603.dat'),
#  Row(file='blk01717.dat'),
#  Row(file='blk01258.dat'),
#  Row(file='blk01072.dat'),
#  Row(file='blk01263.dat'),
#  Row(file='blk01792.dat'),
#  Row(file='blk01512.dat'),
#  Row(file='blk01829.dat'),
#  Row(file='blk01714.dat'),
#  Row(file='blk01043.dat'),
#  Row(file='blk01579.dat'),
#  Row(file='blk01427.dat'),
#  Row(file='blk01872.dat'),
#  Row(file='blk01543.dat'),
#  Row(file='blk01952.dat'),
#  Row(file='blk01909.dat'),
#  Row(file='blk01564.dat'),
#  Row(file='blk01509.dat'),
#  Row(file='blk01788.dat'),
#  Row(file='blk01268.dat'),
#  Row(file='blk01076.dat'),
#  Row(file='blk01022.dat'),
#  Row(file='blk01937.dat'),
#  Row(file='blk01110.dat'),
#  Row(file='blk01772.dat'),
#  Row(file='blk01328.dat'),
#  Row(file='blk01244.dat'),
#  Row(file='blk01396.dat'),
#  Row(file='blk01122.dat'),
#  Row(file='blk01726.dat'),
#  Row(file='blk01083.dat'),
#  Row(file='blk01322.dat'),
#  Row(file='blk01578.dat'),
#  Row(file='blk01919.dat'),
#  Row(file='blk01848.dat'),
#  Row(file='blk01449.dat'),
#  Row(file='blk01071.dat'),
#  Row(file='blk01932.dat'),
#  Row(file='blk01453.dat'),
#  Row(file='blk01385.dat'),
#  Row(file='blk01733.dat'),
#  Row(file='blk01206.dat'),
#  Row(file='blk01352.dat'),
#  Row(file='blk01951.dat'),
#  Row(file='blk01768.dat'),
#  Row(file='blk01704.dat'),
#  Row(file='blk01750.dat'),
#  Row(file='blk01575.dat'),
#  Row(file='blk01486.dat'),
#  Row(file='blk01446.dat'),
#  Row(file='blk01819.dat'),
#  Row(file='blk01444.dat'),
#  Row(file='blk01325.dat'),
#  Row(file='blk01242.dat'),
#  Row(file='blk01878.dat'),
#  Row(file='blk01922.dat'),
#  Row(file='blk01561.dat'),
#  Row(file='blk01853.dat'),
#  Row(file='blk01841.dat'),
#  Row(file='blk01197.dat'),
#  Row(file='blk01888.dat'),
#  Row(file='blk01037.dat'),
#  Row(file='blk01887.dat'),
#  Row(file='blk01968.dat'),
#  Row(file='blk01431.dat'),
#  Row(file='blk01535.dat'),
#  Row(file='blk01443.dat'),
#  Row(file='blk01436.dat'),
#  Row(file='blk01921.dat'),
#  Row(file='blk01609.dat'),
#  Row(file='blk01184.dat'),
#  Row(file='blk01856.dat'),
#  Row(file='blk01182.dat'),
#  Row(file='blk01533.dat'),
#  Row(file='blk01862.dat'),
#  Row(file='blk01223.dat'),
#  Row(file='blk01379.dat'),
#  Row(file='blk01108.dat'),
#  Row(file='blk01866.dat'),
#  Row(file='blk01861.dat'),
#  Row(file='blk01176.dat'),
#  Row(file='blk01689.dat'),
#  Row(file='blk01262.dat'),
#  Row(file='blk01973.dat'),
#  Row(file='blk01569.dat'),
#  Row(file='blk01994.dat'),
#  Row(file='blk01021.dat'),
#  Row(file='blk01236.dat'),
#  Row(file='blk01361.dat'),
#  Row(file='blk01491.dat'),
#  Row(file='blk01086.dat'),
#  Row(file='blk01784.dat'),
#  Row(file='blk01703.dat'),
#  Row(file='blk01944.dat'),
#  Row(file='blk01665.dat'),
#  Row(file='blk01099.dat'),
#  Row(file='blk01903.dat'),
#  Row(file='blk01040.dat'),
#  Row(file='blk01035.dat'),
#  Row(file='blk01496.dat'),
#  Row(file='blk01865.dat'),
#  Row(file='blk01835.dat'),
#  Row(file='blk01977.dat'),
#  Row(file='blk01239.dat'),
#  Row(file='blk01623.dat'),
#  Row(file='blk01523.dat'),
#  Row(file='blk01791.dat'),
#  Row(file='blk01826.dat'),
#  Row(file='blk01854.dat'),
#  Row(file='blk01018.dat'),
#  Row(file='blk01838.dat'),
#  Row(file='blk01011.dat'),
#  Row(file='blk01092.dat'),
#  Row(file='blk01622.dat'),
#  Row(file='blk01447.dat'),
#  Row(file='blk01830.dat'),
#  Row(file='blk01310.dat'),
#  Row(file='blk01549.dat'),
#  Row(file='blk01155.dat'),
#  Row(file='blk01583.dat'),
#  Row(file='blk01629.dat'),
#  Row(file='blk01264.dat'),
#  Row(file='blk01187.dat'),
#  Row(file='blk01842.dat'),
#  Row(file='blk01222.dat'),
#  Row(file='blk01858.dat'),
#  Row(file='blk01655.dat'),
#  Row(file='blk01586.dat'),
#  Row(file='blk01501.dat'),
#  Row(file='blk01971.dat'),
#  Row(file='blk01304.dat'),
#  Row(file='blk01765.dat'),
#  Row(file='blk01031.dat'),
#  Row(file='blk01133.dat'),
#  Row(file='blk01588.dat'),
#  Row(file='blk01351.dat'),
#  Row(file='blk01301.dat'),
#  Row(file='blk01967.dat'),
#  Row(file='blk01573.dat'),
#  Row(file='blk01266.dat'),
#  Row(file='blk01448.dat'),
#  Row(file='blk01822.dat'),
#  Row(file='blk01372.dat'),
#  Row(file='blk01059.dat'),
#  Row(file='blk01089.dat'),
#  Row(file='blk01177.dat'),
#  Row(file='blk01321.dat'),
#  Row(file='blk01712.dat'),
#  Row(file='blk01457.dat'),
#  Row(file='blk01674.dat'),
#  Row(file='blk01191.dat'),
#  Row(file='blk01213.dat'),
#  Row(file='blk01986.dat'),
#  Row(file='blk01506.dat'),
#  Row(file='blk01995.dat'),
#  Row(file='blk01628.dat'),
#  Row(file='blk01631.dat'),
#  Row(file='blk01180.dat'),
#  Row(file='blk01421.dat'),
#  Row(file='blk01161.dat'),
#  Row(file='blk01393.dat'),
#  Row(file='blk01925.dat'),
#  Row(file='blk01824.dat'),
#  Row(file='blk01038.dat'),
#  Row(file='blk01981.dat'),
#  Row(file='blk01927.dat'),
#  Row(file='blk01344.dat'),
#  Row(file='blk01307.dat'),
#  Row(file='blk01540.dat'),
#  Row(file='blk01159.dat'),
#  Row(file='blk01024.dat'),
#  Row(file='blk01845.dat'),
#  Row(file='blk01360.dat'),
#  Row(file='blk01790.dat'),
#  Row(file='blk01281.dat'),
#  Row(file='blk01232.dat'),
#  Row(file='blk01315.dat'),
#  Row(file='blk01324.dat'),
#  Row(file='blk01189.dat'),
#  Row(file='blk01643.dat'),
#  Row(file='blk01208.dat'),
#  Row(file='blk01524.dat'),
#  Row(file='blk01964.dat'),
#  Row(file='blk01497.dat'),
#  Row(file='blk01111.dat'),
#  Row(file='blk01414.dat'),
#  Row(file='blk01014.dat'),
#  Row(file='blk01048.dat'),
#  Row(file='blk01680.dat'),
#  Row(file='blk01168.dat'),
#  Row(file='blk01634.dat'),
#  Row(file='blk01299.dat'),
#  Row(file='blk01494.dat'),
#  Row(file='blk01156.dat'),
#  Row(file='blk01832.dat'),
#  Row(file='blk01451.dat'),
#  Row(file='blk01902.dat'),
#  Row(file='blk01165.dat'),
#  Row(file='blk01490.dat'),
#  Row(file='blk01398.dat'),
#  Row(file='blk01736.dat'),
#  Row(file='blk01228.dat'),
#  Row(file='blk01809.dat'),
#  Row(file='blk01943.dat'),
#  Row(file='blk01120.dat'),
#  Row(file='blk01619.dat'),
#  Row(file='blk01998.dat'),
#  Row(file='blk01868.dat'),
#  Row(file='blk01864.dat'),
#  Row(file='blk01025.dat'),
#  Row(file='blk01734.dat'),
#  Row(file='blk01124.dat'),
#  Row(file='blk01730.dat'),
#  Row(file='blk01525.dat'),
#  Row(file='blk01794.dat'),
#  Row(file='blk01277.dat'),
#  Row(file='blk01419.dat'),
#  Row(file='blk01636.dat'),
#  Row(file='blk01118.dat'),
#  Row(file='blk01077.dat'),
#  Row(file='blk01169.dat'),
#  Row(file='blk01701.dat'),
#  Row(file='blk01087.dat'),
#  Row(file='blk01771.dat'),
#  Row(file='blk01649.dat'),
#  Row(file='blk01787.dat'),
#  Row(file='blk01075.dat'),
#  Row(file='blk01657.dat'),
#  Row(file='blk01850.dat'),
#  Row(file='blk01211.dat'),
#  Row(file='blk01195.dat'),
#  Row(file='blk01417.dat'),
#  Row(file='blk01094.dat'),
#  Row(file='blk01143.dat'),
#  Row(file='blk01492.dat'),
#  Row(file='blk01080.dat'),
#  Row(file='blk01756.dat'),
#  Row(file='blk01259.dat'),
#  Row(file='blk01178.dat'),
#  Row(file='blk01403.dat'),
#  Row(file='blk01085.dat'),
#  Row(file='blk01721.dat'),
#  Row(file='blk01762.dat'),
#  Row(file='blk01130.dat'),
#  Row(file='blk01980.dat'),
#  Row(file='blk01288.dat'),
#  Row(file='blk01285.dat'),
#  Row(file='blk01633.dat'),
#  Row(file='blk01572.dat'),
#  Row(file='blk01433.dat'),
#  Row(file='blk01687.dat'),
#  Row(file='blk01402.dat'),
#  Row(file='blk01046.dat'),
#  Row(file='blk01192.dat'),
#  Row(file='blk01210.dat'),
#  Row(file='blk01764.dat'),
#  Row(file='blk01692.dat'),
#  Row(file='blk01107.dat'),
#  Row(file='blk01376.dat'),
#  Row(file='blk01295.dat'),
#  Row(file='blk01032.dat'),
#  Row(file='blk01146.dat'),
#  Row(file='blk01121.dat'),
#  Row(file='blk01246.dat'),
#  Row(file='blk01463.dat'),
#  Row(file='blk01899.dat'),
#  Row(file='blk01957.dat'),
#  Row(file='blk01196.dat'),
#  Row(file='blk01574.dat'),
#  Row(file='blk01534.dat'),
#  Row(file='blk01785.dat'),
#  Row(file='blk01399.dat'),
#  Row(file='blk01708.dat'),
#  Row(file='blk01248.dat'),
#  Row(file='blk01934.dat'),
#  Row(file='blk01134.dat'),
#  Row(file='blk01913.dat'),
#  Row(file='blk01984.dat'),
#  Row(file='blk01251.dat'),
#  Row(file='blk01181.dat'),
#  Row(file='blk01392.dat'),
#  Row(file='blk01760.dat'),
#  Row(file='blk01149.dat'),
#  Row(file='blk01289.dat'),
#  Row(file='blk01286.dat'),
#  Row(file='blk01562.dat'),
#  Row(file='blk01881.dat'),
#  Row(file='blk01647.dat'),
#  Row(file='blk01751.dat'),
#  Row(file='blk01044.dat'),
#  Row(file='blk01131.dat'),
#  Row(file='blk01298.dat'),
#  Row(file='blk01265.dat'),
#  Row(file='blk01243.dat'),
#  Row(file='blk01831.dat'),
#  Row(file='blk01269.dat'),
#  Row(file='blk01711.dat'),
#  Row(file='blk01558.dat'),
#  Row(file='blk01413.dat'),
#  Row(file='blk01305.dat'),
#  Row(file='blk01323.dat'),
#  Row(file='blk01504.dat'),
#  Row(file='blk01914.dat'),
#  Row(file='blk01005.dat'),
#  Row(file='blk01713.dat'),
#  Row(file='blk01605.dat'),
#  Row(file='blk01199.dat'),
#  Row(file='blk01840.dat'),
#  Row(file='blk01101.dat'),
#  Row(file='blk01129.dat'),
#  Row(file='blk01066.dat'),
#  Row(file='blk01912.dat'),
#  Row(file='blk01284.dat'),
#  Row(file='blk01256.dat'),
#  Row(file='blk01007.dat'),
#  Row(file='blk01104.dat'),
#  Row(file='blk01294.dat'),
#  Row(file='blk01291.dat'),
#  Row(file='blk01359.dat'),
#  Row(file='blk01620.dat'),
#  Row(file='blk01571.dat'),
#  Row(file='blk01686.dat'),
#  Row(file='blk01808.dat'),
#  Row(file='blk01061.dat'),
#  Row(file='blk01127.dat'),
#  Row(file='blk01158.dat'),
#  Row(file='blk01479.dat'),
#  Row(file='blk01455.dat'),
#  Row(file='blk01685.dat'),
#  Row(file='blk01356.dat'),
#  Row(file='blk01467.dat'),
#  Row(file='blk01935.dat'),
#  Row(file='blk01045.dat'),
#  Row(file='blk01428.dat'),
#  Row(file='blk01521.dat'),
#  Row(file='blk01477.dat'),
#  Row(file='blk01978.dat'),
#  Row(file='blk01275.dat'),
#  Row(file='blk01724.dat'),
#  Row(file='blk01482.dat'),
#  Row(file='blk01241.dat'),
#  Row(file='blk01126.dat'),
#  Row(file='blk01313.dat'),
#  Row(file='blk01279.dat'),
#  Row(file='blk01432.dat'),
#  Row(file='blk01097.dat'),
#  Row(file='blk01763.dat'),
#  Row(file='blk01186.dat'),
#  Row(file='blk01375.dat'),
#  Row(file='blk01336.dat'),
#  Row(file='blk01637.dat'),
#  Row(file='blk01642.dat'),
#  Row(file='blk01621.dat'),
#  Row(file='blk01205.dat'),
#  Row(file='blk01084.dat'),
#  Row(file='blk01813.dat'),
#  Row(file='blk01013.dat'),
#  Row(file='blk01970.dat'),
#  Row(file='blk01237.dat'),
#  Row(file='blk01226.dat'),
#  Row(file='blk01758.dat'),
#  Row(file='blk01245.dat'),
#  Row(file='blk01125.dat'),
#  Row(file='blk01855.dat'),
#  Row(file='blk01003.dat'),
#  Row(file='blk01175.dat'),
#  Row(file='blk01867.dat'),
#  Row(file='blk01002.dat'),
#  Row(file='blk01116.dat'),
#  Row(file='blk01329.dat'),
#  Row(file='blk01857.dat'),
#  Row(file='blk01783.dat'),
#  Row(file='blk01167.dat'),
#  Row(file='blk01194.dat'),
#  Row(file='blk01212.dat'),
#  Row(file='blk01869.dat'),
#  Row(file='blk01220.dat'),
#  Row(file='blk01532.dat'),
#  Row(file='blk01312.dat'),
#  Row(file='blk01945.dat'),
#  Row(file='blk01852.dat'),
#  Row(file='blk01908.dat'),
#  Row(file='blk01593.dat'),
#  Row(file='blk01415.dat'),
#  Row(file='blk01698.dat'),
#  Row(file='blk01779.dat'),
#  Row(file='blk01948.dat'),
#  Row(file='blk01207.dat'),
#  Row(file='blk01330.dat'),
#  Row(file='blk01518.dat'),
#  Row(file='blk01570.dat'),
#  Row(file='blk01836.dat'),
#  Row(file='blk01230.dat'),
#  Row(file='blk01350.dat'),
#  Row(file='blk01955.dat'),
#  Row(file='blk01640.dat'),
#  Row(file='blk01815.dat'),
#  Row(file='blk01682.dat'),
#  Row(file='blk01407.dat'),
#  Row(file='blk01529.dat'),
#  Row(file='blk01606.dat'),
#  Row(file='blk01652.dat'),
#  Row(file='blk01742.dat'),
#  Row(file='blk01308.dat'),
#  Row(file='blk01874.dat'),
#  Row(file='blk01592.dat'),
#  Row(file='blk01004.dat'),
#  Row(file='blk01565.dat'),
#  Row(file='blk01020.dat'),
#  Row(file='blk01938.dat'),
#  Row(file='blk01151.dat'),
#  Row(file='blk01599.dat'),
#  Row(file='blk01027.dat'),
#  Row(file='blk01766.dat'),
#  Row(file='blk01216.dat'),
#  Row(file='blk01939.dat'),
#  Row(file='blk01551.dat'),
#  Row(file='blk01801.dat'),
#  Row(file='blk01989.dat'),
#  Row(file='blk01658.dat'),
#  Row(file='blk01567.dat'),
#  Row(file='blk01545.dat'),
#  Row(file='blk01876.dat'),
#  Row(file='blk01611.dat'),
#  Row(file='blk01554.dat'),
#  Row(file='blk01839.dat'),
#  Row(file='blk01602.dat'),
#  Row(file='blk01465.dat'),
#  Row(file='blk01227.dat'),
#  Row(file='blk01716.dat'),
#  Row(file='blk01834.dat'),
#  Row(file='blk01516.dat'),
#  Row(file='blk01875.dat'),
#  Row(file='blk01654.dat'),
#  Row(file='blk01152.dat'),
#  Row(file='blk01666.dat'),
#  Row(file='blk01690.dat'),
#  Row(file='blk01743.dat'),
#  Row(file='blk01920.dat'),
#  Row(file='blk01755.dat'),
#  Row(file='blk01508.dat'),
#  Row(file='blk01370.dat'),
#  Row(file='blk01033.dat'),
#  Row(file='blk01625.dat'),
#  Row(file='blk01673.dat'),
#  Row(file='blk01740.dat'),
#  Row(file='blk01563.dat'),
#  Row(file='blk01527.dat'),
#  Row(file='blk01406.dat'),
#  Row(file='blk01754.dat'),
#  Row(file='blk01339.dat'),
#  Row(file='blk01145.dat'),
#  Row(file='blk01812.dat'),
#  Row(file='blk01466.dat'),
#  Row(file='blk01607.dat'),
#  Row(file='blk01594.dat'),
#  Row(file='blk01006.dat'),
#  Row(file='blk01495.dat'),
#  Row(file='blk01405.dat'),
#  Row(file='blk01214.dat'),
#  Row(file='blk01691.dat'),
#  Row(file='blk01153.dat'),
#  Row(file='blk01568.dat'),
#  Row(file='blk01962.dat'),
#  Row(file='blk01060.dat'),
#  Row(file='blk01410.dat'),
#  Row(file='blk01718.dat'),
#  Row(file='blk01827.dat'),
#  Row(file='blk01425.dat'),
#  Row(file='blk01929.dat'),
#  Row(file='blk01438.dat'),
#  Row(file='blk01135.dat'),
#  Row(file='blk01095.dat'),
#  Row(file='blk01965.dat'),
#  Row(file='blk01983.dat'),
#  Row(file='blk01530.dat'),
#  Row(file='blk01548.dat'),
#  Row(file='blk01709.dat'),
#  Row(file='blk01098.dat'),
#  Row(file='blk01982.dat'),
#  Row(file='blk01270.dat'),
#  Row(file='blk01384.dat'),
#  Row(file='blk01953.dat'),
#  Row(file='blk01688.dat'),
#  Row(file='blk01828.dat'),
#  Row(file='blk01012.dat'),
#  Row(file='blk01185.dat'),
#  Row(file='blk01374.dat'),
#  Row(file='blk01420.dat'),
#  Row(file='blk01614.dat'),
#  Row(file='blk01293.dat'),
#  Row(file='blk01257.dat'),
#  Row(file='blk01019.dat'),
#  Row(file='blk01757.dat'),
#  Row(file='blk01600.dat'),
#  Row(file='blk01910.dat'),
#  Row(file='blk01923.dat'),
#  Row(file='blk01203.dat'),
#  Row(file='blk01651.dat'),
#  Row(file='blk01911.dat'),
#  Row(file='blk01555.dat'),
#  Row(file='blk01877.dat'),
#  Row(file='blk01028.dat'),
#  Row(file='blk01106.dat'),
#  Row(file='blk01974.dat'),
#  Row(file='blk01154.dat'),
#  Row(file='blk01627.dat'),
#  Row(file='blk01416.dat'),
#  Row(file='blk01029.dat'),
#  Row(file='blk01942.dat'),
#  Row(file='blk01803.dat'),
#  Row(file='blk01741.dat'),
#  Row(file='blk01624.dat'),
#  Row(file='blk01699.dat'),
#  Row(file='blk01335.dat'),
#  Row(file='blk01707.dat'),
#  Row(file='blk01577.dat'),
#  Row(file='blk01928.dat'),
#  Row(file='blk01090.dat'),
#  Row(file='blk01846.dat'),
#  Row(file='blk01234.dat'),
#  Row(file='blk01434.dat'),
#  Row(file='blk01481.dat'),
#  Row(file='blk01250.dat'),
#  Row(file='blk01725.dat'),
#  Row(file='blk01961.dat'),
#  Row(file='blk01050.dat'),
#  Row(file='blk01905.dat'),
#  Row(file='blk01979.dat'),
#  Row(file='blk01542.dat'),
#  Row(file='blk01972.dat'),
#  Row(file='blk01016.dat'),
#  Row(file='blk01362.dat'),
#  Row(file='blk01473.dat'),
#  Row(file='blk01993.dat'),
#  Row(file='blk01039.dat'),
#  Row(file='blk01253.dat'),
#  Row(file='blk01507.dat'),
#  Row(file='blk01164.dat'),
#  Row(file='blk01183.dat'),
#  Row(file='blk01380.dat'),
#  Row(file='blk01042.dat'),
#  Row(file='blk01915.dat'),
#  Row(file='blk01229.dat'),
#  Row(file='blk01200.dat'),
#  Row(file='blk01030.dat'),
#  Row(file='blk01052.dat'),
#  Row(file='blk01597.dat'),
#  Row(file='blk01441.dat'),
#  Row(file='blk01770.dat'),
#  Row(file='blk01278.dat'),
#  Row(file='blk01069.dat'),
#  Row(file='blk01440.dat'),
#  Row(file='blk01601.dat'),
#  Row(file='blk01340.dat'),
#  Row(file='blk01517.dat'),
#  Row(file='blk01728.dat'),
#  Row(file='blk01058.dat'),
#  Row(file='blk01723.dat'),
#  Row(file='blk01023.dat'),
#  Row(file='blk01382.dat'),
#  Row(file='blk01276.dat'),
#  Row(file='blk01150.dat'),
#  Row(file='blk01215.dat'),
#  Row(file='blk01252.dat'),
#  Row(file='blk01892.dat'),
#  Row(file='blk01371.dat'),
#  Row(file='blk01536.dat'),
#  Row(file='blk01355.dat'),
#  Row(file='blk01423.dat'),
#  Row(file='blk01209.dat'),
#  Row(file='blk01580.dat'),
#  Row(file='blk01747.dat'),
#  Row(file='blk01429.dat'),
#  Row(file='blk01367.dat'),
#  Row(file='blk01683.dat'),
#  Row(file='blk01505.dat'),
#  Row(file='blk01693.dat'),
#  Row(file='blk01584.dat')]

# %%
# df_blocks.where(df_blocks.time > 1315366304).show(10)
# df_blocks.where(df_blocks.time > 1315366304)

# %%
df_prices = spark.read.parquet(main_data_link + "/price-history")

# %%
# df_prices.show(10)

# %%
# df_inputs = spark.read.parquet(main_data_link + "/dataset-blk01500-01599/inputs").limit(10000000)
df_inputs = spark.read.parquet(main_data_link + "/dataset-blk01000-01999/inputs")

# %%
# df_inputs.show(10)

# %%
df_inputs.where(df_inputs.transaction == df_inputs.parent_transaction).count()
# Out:
# 100000000

# %%
df_inputs.count()
# Out:
# 100000000

# %%
df_outputs = spark.read.parquet(main_data_link + "/dataset-blk01000-01999/outputs")

# %%
# df_outputs.show(10)

# %%
df_transactions = spark.read.parquet(main_data_link + "/dataset-blk01000-01999/transactions")

# %%
# df_transactions.show(10)

# %% [markdown]
# ## Oberve Transaction Relationships

# %% [markdown]
# ### Transaction vs blocks

# %%
# df_transactions.join(df_blocks, df_transactions.hash == df_blocks.hash, "inner").show()
df_transactions.join(df_blocks, df_transactions.hash == df_blocks.hash, "inner")
# Out:
# DataFrame[hash: string, block: string, is_coinbase: boolean, lock_time: bigint, _partition: int, hash: string, time: bigint, file: string, _partition: int]

# %%
# df_transactions.join(df_blocks, df_transactions.block == df_blocks.hash, "inner").show()
df_transactions.join(df_blocks, df_transactions.block == df_blocks.hash, "inner")
# Out:
# DataFrame[hash: string, block: string, is_coinbase: boolean, lock_time: bigint, _partition: int, hash: string, time: bigint, file: string, _partition: int]

# %% [markdown]
# ### Transaction vs Outputs

# %%
# df_transactions.join(df_outputs, df_transactions.hash == df_outputs.transaction, "inner").show()
df_transactions.join(df_outputs, df_transactions.hash == df_outputs.transaction, "inner")
# Out:
# DataFrame[hash: string, block: string, is_coinbase: boolean, lock_time: bigint, _partition: int, transaction: string, index: int, value: bigint, address: string, _partition: int]

# %% [markdown]
# ### Transaction vs Inputs

# %%
# df_transactions.join(df_inputs, df_transactions.hash == df_inputs.transaction, "inner").show()
df_transactions.join(df_inputs, df_transactions.hash == df_inputs.transaction, "inner")
# Out:
# DataFrame[hash: string, block: string, is_coinbase: boolean, lock_time: bigint, _partition: int, transaction: string, index: int, parent_transaction: string, vout: int, _partition: int]

# %%
# df_transactions.where(df_transactions.is_coinbase == True).show(10)
df_transactions.where(df_transactions.is_coinbase == True)
# Out:
# DataFrame[hash: string, block: string, is_coinbase: boolean, lock_time: bigint, _partition: int]

# %%
# df_transactions.where(df_transactions.lock_time > 0).show(10)
df_transactions.where(df_transactions.lock_time > 0)
# Out:
# DataFrame[hash: string, block: string, is_coinbase: boolean, lock_time: bigint, _partition: int]

# %%
# df_transactions.join(df_inputs, df_transactions.hash == df_inputs.transaction, "inner").where(df_transactions.is_coinbase == True).show()
df_transactions.join(df_inputs, df_transactions.hash == df_inputs.transaction, "inner").where(df_transactions.is_coinbase == True)
# Out:
# DataFrame[hash: string, block: string, is_coinbase: boolean, lock_time: bigint, _partition: int, transaction: string, index: int, parent_transaction: string, vout: int, _partition: int]

# %% [markdown]
# ## Blocks vs Inputs

# %%
# df_blocks.join(df_inputs, df_inputs.transaction == df_blocks.hash, "inner").show()
df_blocks.join(df_inputs, df_inputs.transaction == df_blocks.hash, "inner")
# Out:
# DataFrame[hash: string, time: bigint, file: string, _partition: int, transaction: string, index: int, parent_transaction: string, vout: int, _partition: int]

# %% [markdown]
# ## Blocks vs Outputs

# %%
# df_blocks.join(df_outputs, df_outputs.transaction == df_blocks.hash, "inner").show()
df_blocks.join(df_outputs, df_outputs.transaction == df_blocks.hash, "inner")
# Out:
# DataFrame[hash: string, time: bigint, file: string, _partition: int, transaction: string, index: int, value: bigint, address: string, _partition: int]

# %%
# df_blocks.join(df_outputs, df_outputs.address == df_blocks.hash, "inner").show()
df_blocks.join(df_outputs, df_outputs.address == df_blocks.hash, "inner")
# Out:
# DataFrame[hash: string, time: bigint, file: string, _partition: int, transaction: string, index: int, value: bigint, address: string, _partition: int]

# %% [markdown]
# ## Blocks vs Prices

# %%
import numpy as np

# %%
df_blocks.join(df_prices, df_prices.timestamp == df_blocks.time, "inner").where(df_prices.open != np.NaN).count()
# Out:
# 2235

# %%
df_blocks.join(df_prices, df_prices.timestamp == df_blocks.time, "inner").count()
# Out:
# 2290

# %%
# df_prices.where(df_prices.open != np.NaN).show()
df_prices.where(df_prices.open != np.NaN)
# Out:
# DataFrame[timestamp: bigint, open: float, high: float, low: float, close: float, volume_btc: float, volume_usd: float, weighted_price: float]

# %%
df_prices.where(df_prices.open != np.NaN).count()
# Out:
# 3613769

# %%
# import numpy as np

# %%
# np.NaN

# %%
from datetime import datetime

# %%
# a = datetime.fromtimestamp(1538167740)

# %%
# a.year, a.month, a.day

# %% [markdown]
# # Feature Engineering

# %%
get_year = udf(lambda x: datetime.fromtimestamp(x).year)
get_month = udf(lambda x: datetime.fromtimestamp(x).month)
get_day = udf(lambda x: datetime.fromtimestamp(x).day)

# %%
df = df_blocks.withColumn("year", get_year(df_blocks.time))
df = df.withColumn("month", get_month(df.time))
df = df.withColumn("day", get_day(df.time))
df = df.selectExpr(["hash as block_id", "time", "file", "_partition", "year", "month", "day"])
# df.show()

# %%
df_tr_inp = df_transactions.join(df_inputs, df_transactions.hash == df_inputs.transaction, "inner").select("hash", "block", "is_coinbase", "lock_time", "vout")
# df_tr_inp.show()

# %%
df_tr_inp_out = df_tr_inp.join(df_outputs, df_tr_inp.hash == df_outputs.transaction).select("hash", "block", "is_coinbase", "lock_time", "vout", "value")
# df_tr_inp_out.show()

# %%
df_tr_inp_out_bl = df_tr_inp_out.join(df, df_tr_inp_out.block == df.block_id).select("hash", "block", "is_coinbase", "lock_time", "vout", "value", "time", "year", "month", "day", "file")
# df_tr_inp_out_bl.show()

# %%
numerize_coinbase = udf(lambda x: int(x))

# %%
df_tr_inp_out_bl = df_tr_inp_out_bl.withColumn("is_coinbase", numerize_coinbase(df_tr_inp_out_bl.is_coinbase))

# %%
df_tr_inp_out_bl = df_tr_inp_out_bl.withColumn("network_fee", df_tr_inp_out_bl.value - df_tr_inp_out_bl.vout)
# df_tr_inp_out_bl.show(3)

# %%
# .dropDuplicates(['name', 'height']).show()
df_tr_inp_out_bl_dd = df_tr_inp_out_bl.dropDuplicates(['hash', 'block']).sort(df_tr_inp_out_bl.time.desc())

# %%
# df_tr_inp_out_bl_dd.show(3)

# %%
4+5
# Out:
# 9

# %%
network_max_value = df_tr_inp_out_bl_dd.agg({"network_fee": "max"}).collect()[0][0]
network_max_value
# Out:
# 5456513071805

# %%
network_min_value = df_tr_inp_out_bl_dd.agg({"network_fee": "min"}).collect()[0][0]
network_min_value
# Out:
# -7386

# %%
network_std_value = df_tr_inp_out_bl_dd.agg({"network_fee": "std"}).collect()[0][0]
network_std_value
# Out:
# 5044428282.184236

# %%
network_mean_value = df_tr_inp_out_bl_dd.agg({"network_fee": "mean"}).collect()[0][0]
network_mean_value
# Out:
# 118450519.78025664

# %%
normalize_network_min_max = udf(lambda x: (x - network_min_value)/(network_max_value - network_min_value))
normalize_network_std = udf(lambda x: (x - network_mean_value)/network_std_value)

# %%
df_tr_inp_out_bl_dd = df_tr_inp_out_bl_dd.withColumn("network_normalized", normalize_network_std(df_tr_inp_out_bl_dd.network_fee))
# df_tr_inp_out_bl_dd.show()

# %%
df_tr_inp_out_bl_dd.write.parquet(main_data_link + "/all_combo.parquet", mode="overwrite")

# %%
formed_df = spark.read.parquet(main_data_link + "/all_combo.parquet")
# formed_df.show()

# %%
# formed_df.where((formed_df.year == 2012) & (formed_df.month == 5)).show()
formed_df.where((formed_df.year == 2012) & (formed_df.month == 5))
# Out:
# DataFrame[hash: string, block: string, is_coinbase: string, lock_time: bigint, vout: int, value: bigint, time: bigint, year: string, month: string, day: string, file: string, network_fee: bigint, network_normalized: string]

# %%
formed_df.count()
# Out:
# 45580499

# %%
df_prices = df_prices.withColumn("year", get_year(df_prices.timestamp))
df_prices = df_prices.withColumn("month", get_month(df_prices.timestamp))
df_prices = df_prices.withColumn("day", get_day(df_prices.timestamp))
# df_prices = df_prices.selectExpr(["hash as block_id", "time", "file", "_partition", "year", "month", "day"])
# df_prices.show()

# %%
df_prices = df_prices.where((df_prices.open != np.NaN))
# df_prices.show()

# %%
df_day_prices = df_prices.groupBy("year", "month", "day").agg(avg("weighted_price"), avg("volume_btc"), count("*")).withColumnRenamed("avg(weighted_price)","day_w_price").withColumnRenamed("avg(volume_btc)","day_volume_btc").withColumnRenamed("count(1)","day_samples")

# df_day_prices.show()

# %%
df_day_formed = formed_df.groupBy("year", "month", "day").agg(avg("network_fee"), count("*")).withColumnRenamed("avg(network_fee)","day_network_fee").withColumnRenamed("count(1)","day_samples_tr")
# df_day_formed.show()

# %%
day_network_std_value = df_day_formed.agg({"day_network_fee": "std"}).collect()[0][0]
day_network_mean_value = df_day_formed.agg({"day_network_fee": "mean"}).collect()[0][0]
normalize_day_network_std = udf(lambda x: (x - day_network_mean_value)/day_network_std_value)
df_day_network_norm = df_day_formed.withColumn("network_normalized", normalize_day_network_std(df_day_formed.day_network_fee))
# df_day_network_norm.show()

# %%
df_day_network_norm = df_day_network_norm.selectExpr(["year as year_n", "month as month_n", "day as day_n", "day_network_fee", "day_samples_tr", "network_normalized"])
# df_day_network_norm.show(4)

# %%
ddf = df_day_network_norm.join(df_day_prices, (df_day_network_norm.year_n == df_day_prices.year) & (df_day_network_norm.month_n == df_day_prices.month) & (df_day_network_norm.day_n == df_day_prices.day))
# ddf.show()

# %%
ddf.count()
# Out:
# 391

# %%
# ddf.show()

# %%
ddf = ddf.select(["year", "month", "day", "network_normalized", "day_samples_tr", "day_w_price", "day_volume_btc", "day_samples"])

# %%
from pyspark.sql.types import IntegerType
ddf = ddf.withColumn("year", ddf["year"].cast(IntegerType()))
ddf = ddf.withColumn("month", ddf["month"].cast(IntegerType()))
ddf = ddf.withColumn("day", ddf["day"].cast(IntegerType()))

# %%
ddf = ddf.sort(ddf.year.desc(), ddf.month.desc(), ddf.day.desc())

# %%
# ddf.show()

# %%
from pyspark.sql.functions import monotonically_increasing_id

ddf = ddf.withColumn("id", monotonically_increasing_id())

# %%
# ddf.show()

# %%
from pyspark.sql import Window
from pyspark.sql import SparkSession, functions as F

window = Window.orderBy(F.col('id'))
ddf = ddf.withColumn('row_number', F.row_number().over(window))

# %%
# ddf.show()

# %%
# Assign Window
assign_7_day_window = udf(lambda x: int(x/7))
ddf = ddf.withColumn('week_id', assign_7_day_window(ddf.row_number))

# %%
# ddf.show()

# %%
unq_weeks = [x[0] for x in ddf.select("week_id").distinct().collect()]
unq_weeks
# Out:
# ['7',
#  '51',
#  '15',
#  '54',
#  '11',
#  '29',
#  '42',
#  '3',
#  '30',
#  '34',
#  '8',
#  '22',
#  '28',
#  '16',
#  '35',
#  '52',
#  '0',
#  '47',
#  '43',
#  '5',
#  '31',
#  '18',
#  '27',
#  '17',
#  '26',
#  '46',
#  '6',
#  '19',
#  '23',
#  '41',
#  '55',
#  '38',
#  '40',
#  '25',
#  '44',
#  '53',
#  '33',
#  '48',
#  '9',
#  '24',
#  '32',
#  '1',
#  '20',
#  '36',
#  '10',
#  '37',
#  '49',
#  '4',
#  '39',
#  '12',
#  '13',
#  '14',
#  '21',
#  '2',
#  '50',
#  '45']

# %%
ddf.write.parquet(main_data_link + "/weekly_finalized.parquet", mode="overwrite")

# %%
ddf = spark.read.parquet(main_data_link + "/weekly_finalized.parquet")
# ddf.show()

# %%
ddf.count()
# Out:
# 391

# %%
import pandas as pd

# %%
main_df = list()

for uq_week in unq_weeks:
  pdf = ddf.where(ddf.week_id == uq_week).toPandas()
  pdf = pdf.sort_values(by=['row_number'])
  day_w_price_list = pdf["day_w_price"].tolist()
  day_volume_btc_list = pdf["day_volume_btc"].tolist()
  day_samples_list = pdf["day_samples"].tolist()
  day_samples_tr_list = pdf["day_samples_tr"].tolist()
  network_normalized_list = pdf["network_normalized"].tolist()
  week_label_id = pdf["week_id"].tolist()

  for i in range(7 - len(day_w_price_list)):
    day_w_price_list.append(0.0)
    day_volume_btc_list.append(0.0)
    day_samples_list.append(0.0)
    day_samples_tr_list.append(0.0)
    network_normalized_list.append(0.0)


  new_df = pd.DataFrame()
  for i in range(7):
    new_df["week_id"] = [week_label_id[0],]
    new_df["day_w_price_{0}".format(i)] = [day_w_price_list[i],]
    new_df["day_volume_btc_{0}".format(i)] = [day_volume_btc_list[i],]
    new_df["day_samples_list_{0}".format(i)] = [day_samples_list[i],]
    new_df["day_samples_tr_list_{0}".format(i)] = [day_samples_tr_list[i],]
    new_df["network_normalized_{0}".format(i)] = [network_normalized_list[i],]

  main_df.append(new_df)

# %%
pdf_final = pd.concat(main_df)

# %%
pdf_final["network_normalized_6"] = pdf_final["network_normalized_6"].apply(lambda x: float(x))
pdf_final["network_normalized_4"] = pdf_final["network_normalized_4"].apply(lambda x: float(x))
pdf_final["network_normalized_5"] = pdf_final["network_normalized_5"].apply(lambda x: float(x))

# %%
pdf_final
# Out:
#   week_id  day_w_price_0  day_volume_btc_0  day_samples_list_0  \
# 0       7    7430.027208          1.918692                1411
# 0      51    5890.569028         11.811032                1362
# 0      15   10316.605587          2.684358                1399
# 0      54    4395.624039          5.976714                1382
# 0      11    7880.584322         13.282693                1439
# 0      29    4980.670540          9.158753                1422
# 0      42    6499.971607          3.351327                1372
# 0       3    9922.395657          5.250464                1440
# 0      30    3908.236848          3.201487                1348
# 0      34    3575.310058          5.002983                1181
# 0       8    7319.050657          1.782264                1432
# 0      22    7896.830021          3.869469                1435
# 0      28    5047.457164          5.698047                1414
# 0      16   10563.647525          7.074841                1426
# 0      35    3700.678702          4.220989                1220
# 0      52    6072.970271         10.716974                1433
# 0       0    5294.226220         37.791418                1440
# 0      47   16200.092354         11.516474                1440
# 0      43    6573.830820          3.506731                1381
# 0       5    8847.166835          6.109492                1438
# 0      31    3906.534462          5.875856                1371
# 0      18    9857.746980          5.532850                1431
# 0      27    5317.854807          5.087161                1401
# 0      17   10100.656941          2.894140                1366
# 0      26    5304.521236          3.013088                1397
# 0      46   18318.874101         14.960485                1439
# 0       6    8111.715363          1.447948                1420
# 0      19   10472.448824          9.607984                1435
# 0      23    7850.979305         10.928512                1417
# 0      41    6658.831358          6.112686                1402
# 0      55    3822.076284         10.753613                1393
# 0      38    6365.113235          2.524023                1275
# 0      40    6665.873696          5.553815                1376
# 0      25    6047.488286          6.337223                1433
# 0      44    7784.482609         12.247154                1440
# 0      53    5617.707418         19.337999                1439
# 0      33    3413.938069          2.580815                1257
# 0      48   10194.258502         11.610863                1439
# 0       9    7242.510172          3.867925                1435
# 0      24    7702.740476          5.820832                1438
# 0      32    3568.821388          4.474067                1321
# 0       1    8761.143354          2.330252                1439
# 0      20   11415.369258          5.538371                1425
# 0      36    3773.259865          8.381701                1408
# 0      10    9335.804953          3.288898                1420
# 0      37    3508.657608          9.665287                1427
# 0      49    8157.120609          9.504522                1440
# 0       4    8723.535475          6.703676                1435
# 0      39    6586.956407          1.760305                1281
# 0      12    8358.546978          3.104248                1432
# 0      13    8257.532900          3.444043                1438
# 0      14   10174.286766          3.208758                1391
# 0      21   10724.805016          9.520347                1440
# 0       2    9846.395998          4.693783                1439
# 0      50    6960.031584         18.585388                1432
# 0      45   14816.625461         10.419457                1440
#
#    day_samples_tr_list_0   network_normalized_0  day_w_price_1  \
# 0                  21224    -0.8263104408081492    7150.839260
# 0                  24572     0.9085677941450381    5748.121116
# 0                  10930    -0.6745704100402417   10220.789596
# 0                 189502     1.7631711833272004    4290.272280
# 0                 131870    -0.3860067055185775    7450.100642
# 0                 220978    -0.3106972448623404    4971.545803
# 0                   1390    -1.0215882952170843    6441.487447
# 0                 146275    -0.4325285795440584   10080.722378
# 0                 272306    -0.4835306433672619    3995.972001
# 0                 254952    -0.5498295518975886    3626.334447
# 0                 143777    -0.9226556363930446    7309.541875
# 0                  92732   0.055809346960333475    7819.548641
# 0                  20405    0.46604316585717104    5129.666958
# 0                 129185    -0.5595947958429208   10522.250226
# 0                  53448    -0.7524949417220067    3756.609192
# 0                  80737     0.8650937332165715    5789.820457
# 0                  54051     1.4797461957100926    6666.828860
# 0                 197512     1.6592392119548205   14132.601705
# 0                 157317   -0.19190547578252906    6541.718834
# 0                  13153   -0.42185313272392383    8891.817031
# 0                 213069     -0.140582934072062    3910.910261
# 0                 284925    -0.7806264780216526    9540.448918
# 0                 162759    0.06856763741625783    5287.273099
# 0                 181805    -1.0202725522699536   11378.232866
# 0                  20043    -0.6530750101751059    5200.883934
# 0                 194488   -0.17635407077652795   18716.811442
# 0                 131940    -0.9558626991957355    8113.360820
# 0                   4627    -0.9164032417490602   11428.597798
# 0                  24089   -0.35934685735036404    8648.244331
# 0                 117548    0.11588833375966978    6412.211312
# 0                   5909     0.6803351331243477    3694.980824
# 0                  49492    -0.5261463013341404    6448.400233
# 0                  34900     0.4379436634075675    6521.758679
# 0                 173739  -0.058494796420534366    5844.480875
# 0                  29452     0.9190007202433298    8232.819023
# 0                 239828     1.6025861651795346    5116.371163
# 0                  19330     -0.806217799533128    3416.594530
# 0                  19521     0.5328563802764843    9832.286237
# 0                 265466   -0.47507319923699265    7341.804980
# 0                 212925    -0.3270608721804323    7890.294524
# 0                  29644    -0.8737041569245164    3581.973572
# 0                 157089    -0.6861445024655638    8791.293453
# 0                  81825    -0.9063395162611751   11139.493769
# 0                 123068    -0.3769818236550998    4126.211926
# 0                  66262    -1.0792361871101543    9343.976275
# 0                   1443    -1.1465717144094796    4074.566440
# 0                 204766     2.0919775722609213    8090.706969
# 0                  84544    -0.7587847080059342    8430.129192
# 0                 154372    -0.4811428640269296    6588.155310
# 0                  16742    -1.1376542173023079    8334.023260
# 0                 279874    -0.8393350863682444    8039.224140
# 0                 333512    -0.5480213730624972    9989.622671
# 0                  45863     1.0646875667746283    9801.486003
# 0                 246552     -0.572700156886899    9720.587407
# 0                 159681      2.193253072509186    7244.039985
# 0                  32927   0.007454204284326103   14962.379084
#
#    day_volume_btc_1  day_samples_list_1  day_samples_tr_list_1  ...  \
# 0          2.243633                1427                  36141  ...
# 0          4.409447                1344                  55529  ...
# 0          3.337336                1396                  26776  ...
# 0          5.397706                1336                 185892  ...
# 0          3.480100                1436                 222440  ...
# 0         11.063406                1437                  43205  ...
# 0          5.080253                1375                  33585  ...
# 0          3.356732                1439                 137027  ...
# 0          4.595257                1359                  25049  ...
# 0          2.781094                1145                  50370  ...
# 0          3.030343                1427                 314730  ...
# 0          5.007419                1428                 163159  ...
# 0         10.475265                1437                 259345  ...
# 0          8.002474                1430                 219594  ...
# 0          5.220958                1277                 259684  ...
# 0         10.655193                1418                 186452  ...
# 0         40.634298                1440                  80544  ...
# 0         12.838877                1440                 206632  ...
# 0          3.797963                1437                  25151  ...
# 0          2.555948                1439                 272762  ...
# 0          7.074196                1393                  53827  ...
# 0          3.878046                1427                  30782  ...
# 0          3.380321                1370                  36934  ...
# 0          3.139950                1389                 161455  ...
# 0          3.557546                1421                 174165  ...
# 0         10.193709                1440                  20980  ...
# 0          2.636275                1437                  51008  ...
# 0          6.571976                1429                 234431  ...
# 0          5.266846                1440                 207065  ...
# 0          3.790370                1366                  10076  ...
# 0          4.796407                1357                   4714  ...
# 0          3.065667                1294                 246839  ...
# 0          4.110923                1378                 231330  ...
# 0          4.422963                1429                  77703  ...
# 0          6.320181                1440                    875  ...
# 0         13.966499                1426                 276748  ...
# 0          4.970035                1340                 228012  ...
# 0          7.793558                1439                 235511  ...
# 0         13.982034                1439                  10719  ...
# 0          5.835179                1439                  25755  ...
# 0          6.078132                1315                 213237  ...
# 0          3.217493                1439                  43711  ...
# 0          8.282338                1436                   6739  ...
# 0          8.547594                1406                  17488  ...
# 0          3.460444                1439                 332839  ...
# 0         10.238504                1403                   8713  ...
# 0          5.723903                1429                 101680  ...
# 0          4.465201                1420                  17566  ...
# 0          3.219451                1267                  86838  ...
# 0          1.270906                1439                 222555  ...
# 0          7.089158                1434                 151769  ...
# 0          5.210281                1431                 242760  ...
# 0          8.717430                1440                 286005  ...
# 0          4.106392                1440                  23708  ...
# 0         10.277268                1440                 175915  ...
# 0          8.524306                1440                 199304  ...
#
#   day_w_price_5  day_volume_btc_5  day_samples_list_5  day_samples_tr_list_5  \
# 0   7405.110024          2.908053                1433                  22465
# 0   5658.646806         12.080170                1431                 176779
# 0  10659.807005          7.515105                1424                   4104
# 0   4037.267978         10.654303                1415                 118665
# 0   8064.522900          6.019777                1436                   4959
# 0   4088.429469          1.962899                1224                   8845
# 0   6705.525896          4.982766                1438                  12304
# 0   9403.167146          5.611669                1437                   8555
# 0   3793.163625          6.425718                1375                 107625
# 0   4006.822504          8.697562                1359                  11582
# 0   7522.175874          4.819475                1437                  11083
# 0   7751.680285          6.068518                1440                  80486
# 0   5128.484705          7.816333                1391                  38155
# 0  10042.669021          6.560759                1418                  37759
# 0   3717.518934          8.470345                1399                 156380
# 0   5608.239017          8.203942                1407                  15109
# 0   9019.792646          4.481366                1439                  17047
# 0  11291.622580          9.915408                1436                  96300
# 0   7486.139528          7.025657                1436                  45735
# 0   8574.611716         11.812106                1440                 155615
# 0   3587.674876          2.810185                1225                   8763
# 0  10577.614458          3.997274                1408                 123291
# 0   5121.256871          5.321157                1395                 144294
# 0  10475.070739          6.494309                1430                  37340
# 0   5149.359098         10.483335                1434                   4570
# 0  16539.760741         11.900490                1440                 202879
# 0   7929.897115          8.449147                1439                 173186
# 0  11794.103588          8.282464                1437                 199072
# 0   8046.300618          2.344249                1434                 295457
# 0   6481.711971          1.001484                1097                 101748
# 0   3634.043061          8.389321                1403                  40209
# 0   6369.730655          2.563580                1043                   4267
# 0   6707.643348          2.741608                1185                  64941
# 0   5694.984819          5.945227                1434                 349250
# 0  16665.268814          6.597928                1440                  66280
# 0   4359.781138          6.159781                1360                 116785
# 0   3640.293341          6.180842                1304                  28428
# 0   8174.598072          5.478116                1426                 142084
# 0   8470.017929          0.835508                1413                  28809
# 0   6806.487474         15.518718                1439                 122957
# 0   3371.277252          4.732002                1297                 144430
# 0   9490.032454          4.364144                1439                 282564
# 0  11315.817041          8.426091                1440                   4424
# 0   3923.330942         18.134580                1433                  65392
# 0   9413.283676         12.418314                1432                   7557
# 0   3850.935916         17.033485                1430                  27494
# 0   6113.264262         26.039886                1433                  52564
# 0   8646.193569          2.360702                1438                 315210
# 0   6574.020801          3.625125                1323                 139679
# 0   8146.725817          4.363295                1439                  19066
# 0   9978.878327          2.384239                1348                 201346
# 0  10316.665200          1.758013                1307                 268065
# 0   8169.588226          5.029743                1439                  77774
# 0  10344.239496          4.550979                1440                  40212
# 0   6241.215409          9.453034                1420                  75185
# 0  16219.341424         14.151292                1440                  48118
#
#    network_normalized_5 day_w_price_6  day_volume_btc_6  day_samples_list_6  \
# 0             -0.562029   7328.986917          3.227925              1438.0
# 0              1.598936   5866.644507         10.896684              1407.0
# 0             -0.798960  10564.875488          3.235529              1408.0
# 0              2.837390   3914.694761          7.138007              1403.0
# 0             -0.517398   8264.189837          3.515443              1435.0
# 0             -0.585784   3994.073714          5.822625              1400.0
# 0              2.490874   6738.872120          3.636640              1415.0
# 0             -0.679669   9041.676245          6.647366              1439.0
# 0             -0.070846   3985.170884          9.889859              1389.0
# 0             -0.685845   4022.403776          5.502658              1353.0
# 0             -0.978519   7252.149431         10.540328              1438.0
# 0             -0.217491   7773.477740          6.388959              1439.0
# 0             -0.483999   5044.045358          7.271957              1382.0
# 0             -0.754452  10345.745634          5.036314              1423.0
# 0             -0.187666   3778.891885          7.303471              1378.0
# 0              0.462947   5666.540045          5.977922              1407.0
# 0             -0.731803      0.000000          0.000000                 0.0
# 0              1.886713  10937.496735          6.448964              1437.0
# 0              0.875871   7537.930288          8.100393              1438.0
# 0             -0.404935   8102.893845          2.799329              1433.0
# 0             -0.831163   3570.444199          4.734068              1317.0
# 0             -0.624835  10680.276555          6.963434              1431.0
# 0              0.149529   5078.929241          2.546928              1352.0
# 0             -0.703725  10085.104552          5.360595              1433.0
# 0             -0.695063   5532.974691          7.110458              1425.0
# 0              1.981166  16730.288686          9.400481              1438.0
# 0             -0.713422   7533.920321          4.708385              1429.0
# 0             -0.564902  11311.476750          4.673465              1430.0
# 0             -0.530428   7983.344121          6.499286              1440.0
# 0              0.178649   6520.305922          1.187506              1119.0
# 0              1.366020   3695.818631         16.217247              1428.0
# 0             -0.759153   6515.361009          3.970143              1304.0
# 0             -0.676257   6705.600148          4.138515              1327.0
# 0             -0.464701   5618.799696          8.918953              1424.0
# 0              0.634991  15790.446138         11.283969              1440.0
# 0              1.189246   4256.718232          6.105847              1379.0
# 0             -0.168745   3582.604522          7.468767              1329.0
# 0              2.205119   8194.445674          5.661234              1427.0
# 0             -1.015780   9237.518970          2.796045              1422.0
# 0              0.131410   6290.828120          9.618451              1437.0
# 0             -0.291166   3419.317976          3.193074              1267.0
# 0             -0.782777   9735.050461          4.084092              1439.0
# 0             -0.103239  10846.846268          5.727357              1440.0
# 0              0.451060   3748.438946         14.742229              1433.0
# 0             -1.091469   9318.768121         26.948401              1438.0
# 0             -0.100468   3756.932172         18.860103              1430.0
# 0              3.482985   6554.555889         10.456755              1429.0
# 0             -0.878285   8644.707992          3.071715              1439.0
# 0             -0.032217   6578.164628          2.026690              1225.0
# 0             -0.757810   8244.961883          6.097492              1427.0
# 0             -0.890516  10038.312745          3.064180              1354.0
# 0             -0.905929  10341.913353          2.032253              1307.0
# 0              0.179633   8036.509588          5.972954              1436.0
# 0             -0.431876   9957.716394          5.648086              1439.0
# 0              2.141705   6122.311361          6.752217              1418.0
# 0             -0.045859  16831.690378         21.647381              1440.0
#
#    day_samples_tr_list_6  network_normalized_6
# 0               254832.0             -0.861857
# 0                20005.0              2.793125
# 0               180917.0             -0.566583
# 0               139437.0              1.717022
# 0               286759.0             -0.699546
# 0                28975.0             -0.821035
# 0                63196.0              0.270415
# 0               141929.0             -0.845806
# 0               196987.0             -0.259521
# 0                 7764.0              0.167691
# 0                 5177.0             -1.199023
# 0               150634.0              0.110887
# 0               244107.0             -0.639952
# 0               109371.0             -0.540395
# 0               141475.0             -0.155776
# 0                70628.0              0.998136
# 0                    0.0              0.000000
# 0               157490.0              1.548938
# 0               183629.0              0.455850
# 0                65957.0             -1.019046
# 0                 6631.0             -0.072307
# 0                20536.0             -0.668176
# 0               145369.0             -0.417173
# 0               218037.0             -0.643521
# 0                90826.0              1.538661
# 0               157277.0              1.794392
# 0                61270.0             -0.372338
# 0               213945.0             -0.687278
# 0               174906.0             -0.149738
# 0                52723.0             -0.383524
# 0               218932.0              2.090079
# 0                76386.0             -0.160615
# 0               149463.0             -0.424613
# 0               224532.0             -0.123541
# 0               205787.0              0.754599
# 0               152764.0              1.528421
# 0               274791.0             -0.351237
# 0               182981.0              1.663854
# 0               230900.0             -0.613965
# 0               141839.0             -0.037864
# 0                23639.0             -0.723423
# 0                17065.0             -1.054257
# 0                11104.0              0.328581
# 0                 5184.0              1.028729
# 0               121623.0             -0.622823
# 0                 7234.0              0.143156
# 0               119271.0              2.813732
# 0               308854.0             -0.721748
# 0               114019.0             -0.476754
# 0               279963.0             -0.739564
# 0               328664.0             -0.710362
# 0               296523.0             -0.750844
# 0               152394.0             -0.098150
# 0                31563.0              0.286280
# 0               173978.0              1.148789
# 0               151473.0              0.190281
#
# [56 rows x 36 columns]

# %%
sparkDF = spark.createDataFrame(pdf_final)

# %%
# sparkDF.show()

# %%
weekly_price = ddf.selectExpr(["row_number", "week_id", "day_w_price as week_day_end_price"]).dropDuplicates(['week_id'])
weekly_price.show()
# Out:
# +----------+-------+------------------+
# |row_number|week_id|week_day_end_price|
# +----------+-------+------------------+
# |        49|      7| 7430.027208443147|
# |       357|     51|  5890.56902798332|
# |       105|     15|10316.605586719308|
# |       378|     54| 4395.624038630042|
# |        77|     11| 7880.584321658921|
# |       203|     29| 4980.670540295908|
# |       294|     42| 6499.971607441805|
# |        21|      3| 9922.395657009549|
# |       210|     30|3908.2368477388377|
# |       238|     34|3575.3100575601316|
# |        56|      8| 7319.050657474795|
# |       154|     22| 7896.830021300631|
# |       196|     28| 5047.457163507227|
# |       112|     16|10563.647525311186|
# |       245|     35|3700.6787021324285|
# |       364|     52| 6072.970271406686|
# |         1|      0| 5294.226220364041|
# |       329|     47|16200.092354329427|
# |       301|     43|   6573.8308199165|
# |        35|      5| 8847.166835312717|
# +----------+-------+------------------+
# only showing top 20 rows

# %%
weekly_price.write.parquet(main_data_link + "/weekly_labels.parquet", mode = "Overwrite")

# %%
w_price = spark.read.parquet(main_data_link + "/weekly_labels.parquet")
w_price.count()
# Out:
# 56

# %%
# sparkDF.show()

# %%
decrease_val = udf(lambda x: int(x) - 1)


sparkDF = sparkDF.withColumn("previous_week_id", decrease_val(sparkDF.week_id))
# sparkDF.show()

# %%
final_col_list  = list()
for i in range(7):
  final_col_list.append("day_w_price_{0}".format(i))
  final_col_list.append("day_volume_btc_{0}".format(i))
  final_col_list.append("day_samples_list_{0}".format(i))
  final_col_list.append("day_samples_tr_list_{0}".format(i))
  final_col_list.append("network_normalized_{0}".format(i))


final_col_list.append("week_day_end_price")

train_df = sparkDF.join(w_price, sparkDF.previous_week_id == w_price.week_id).select(final_col_list)
# train_df.show()

# %%
from pyspark.sql.types import IntegerType, FloatType

for col in final_col_list:
  train_df = train_df.withColumn(col, train_df[col].cast(FloatType()))

# %%
from pyspark.ml.feature import VectorAssembler

# %%
assembler = VectorAssembler(
    inputCols=final_col_list[:-1],
    outputCol="features")

# %%
output = assembler.transform(train_df).select('features','week_day_end_price')
output.show()
# Out:
# +--------------------+------------------+
# |            features|week_day_end_price|
# +--------------------+------------------+
# |[7430.02734375,1....|         8111.7153|
# |[5890.56884765625...|         6960.0317|
# |[10316.60546875,2...|         10174.287|
# |[4395.6240234375,...|         5617.7075|
# |[7880.58447265625...|          9335.805|
# |[4980.67041015625...|          5047.457|
# |[6499.9716796875,...|         6658.8315|
# |[9922.3955078125,...|          9846.396|
# |[3908.23681640625...|         4980.6704|
# |[3575.31005859375...|          3413.938|
# |[7319.05078125,1....|         7430.0273|
# |[7896.830078125,3...|         10724.805|
# |[5047.45703125,5....|          5317.855|
# |[10563.6474609375...|         10316.605|
# |[3700.6787109375,...|           3575.31|
# |[6072.97021484375...|          5890.569|
# |[16200.0927734375...|         18318.875|
# |[6573.8310546875,...|         6499.9717|
# |[8847.1669921875,...|          8723.535|
# |[3906.53442382812...|         3908.2368|
# +--------------------+------------------+
# only showing top 20 rows

# %%
train,test = output.randomSplit([0.75, 0.25])
# train,test = output.randomSplit([0.5, 0.5])

# %% [markdown]
# #Simple Linear Regressor

# %%
from pyspark.ml.regression import LinearRegression
lin_reg = LinearRegression(featuresCol = 'features', labelCol='week_day_end_price')
linear_model = lin_reg.fit(train)
print("Coefficients: " + str(linear_model.coefficients))
print("\nIntercept: " + str(linear_model.intercept))
# Out:
# Coefficients: [1.667550775867644,-9.616218238964247,7.87870632812789,0.0017980433676442573,-642.4923895794335,-0.922841499700496,-96.68455035125466,-6.51364434340936,0.0048556084124388305,476.10915093063335,1.5654816358245776,36.18545770208855,3.2258433604933665,0.0017278215949789045,-826.579690864425,-2.231855467231347,28.494113158206925,3.129104454281954,0.001682640578394212,921.7580013370822,1.6768565451481199,9.341080488081635,5.4489751583905175,-0.003290142697978702,-417.8948045851574,-1.269476657873392,-18.860230756653525,3.3199059859174893,8.76233625648121e-06,187.97057939596237,0.36631939594668994,-108.24940378326987,-6.527365455172211,0.0038284387939307263,284.81225238464947]
#
# Intercept: -13363.58030417038

# %%
trainSummary = linear_model.summary
print("RMSE: %f" % trainSummary.rootMeanSquaredError)
print("\nr2: %f" % trainSummary.r2)
# Out:
# RMSE: 585.115035
#
# r2: 0.955209

# %%
from  pyspark.sql.functions import abs
predictions = linear_model.transform(test)
x =((predictions['week_day_end_price']-predictions['prediction'])/predictions['week_day_end_price'])*100
predictions = predictions.withColumn('Accuracy',abs(x))
predictions.select("prediction","week_day_end_price","Accuracy","features").show()
# Out:
# +------------------+------------------+------------------+--------------------+
# |        prediction|week_day_end_price|          Accuracy|            features|
# +------------------+------------------+------------------+--------------------+
# | 3447.328830945524|         4980.6704| 30.78584714387121|[3908.23681640625...|
# | 8712.423141158135|         10724.805| 18.76380600839604|[7896.830078125,3...|
# |24254.865809400526|         18318.875| 32.40368641306044|[16200.0927734375...|
# |3001.8487799472096|         3908.2368|23.191737835694756|[3906.53442382812...|
# | 4933.408397469797|         3508.6577| 40.60671625500794|[6365.11328125,2....|
# | 6275.856839256947|         6665.8735| 5.850946523997639|[6658.83154296875...|
# | 1582.585368284781|         3700.6787|57.235267044194124|[3773.259765625,8...|
# |  9348.30243727726|          8358.547|11.841239596772134|[8257.533203125,3...|
# | 9716.368963993118|         7880.5845| 23.29502967332693|[8358.546875,3.10...|
# |11932.124225292166|          8257.533|44.499863721729206|[10174.287109375,...|
# | 8897.618546366135|         8157.1206| 9.077932970623673|[6960.03173828125...|
# +------------------+------------------+------------------+--------------------+

# %% [markdown]
# #Random Forest Regressor

# %%
from pyspark.ml.regression import RandomForestRegressor
rf = RandomForestRegressor(featuresCol = 'features', labelCol='week_day_end_price')
rf_model = rf.fit(train)

# %%
from  pyspark.sql.functions import abs

predictions_rf = rf_model.transform(test)
x_rf =((predictions_rf['week_day_end_price']-predictions_rf['prediction'])/predictions_rf['week_day_end_price'])*100
predictions_rf = predictions_rf.withColumn('Accuracy',abs(x_rf))
predictions_rf.select("prediction","week_day_end_price","Accuracy","features").show()
# Out:
# +------------------+------------------+------------------+--------------------+
# |        prediction|week_day_end_price|          Accuracy|            features|
# +------------------+------------------+------------------+--------------------+
# | 4080.753646850586|         4980.6704|18.068185388670045|[3908.23681640625...|
# | 8720.291426440112|         10724.805| 18.69044070701067|[7896.830078125,3...|
# |11852.519312608509|         18318.875| 35.29886899381917|[16200.0927734375...|
# | 4259.150422973633|         3908.2368| 8.978821475052253|[3906.53442382812...|
# | 6992.888114832758|         3508.6577| 99.30379886440905|[6365.11328125,2....|
# |6408.9331472685835|         6665.8735|3.8545643947870625|[6658.83154296875...|
# | 4765.478233642578|         3700.6787| 28.77308747603572|[3773.259765625,8...|
# | 8711.745122365428|          8358.547| 4.225593905823827|[8257.533203125,3...|
# | 8964.870415101663|         7880.5845|13.758953364533133|[8358.546875,3.10...|
# | 9471.022994506307|          8257.533|14.695548434756175|[10174.287109375,...|
# |7213.6443246993485|         8157.1206|11.566290685182096|[6960.03173828125...|
# +------------------+------------------+------------------+--------------------+

# %%
from pyspark.ml.evaluation import RegressionEvaluator

evaluator_rf = RegressionEvaluator(
    labelCol="week_day_end_price", predictionCol="prediction", metricName="rmse")
rmse_rf = evaluator_rf.evaluate(predictions_rf)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse_rf)
# Out:
# Root Mean Squared Error (RMSE) on test data = 2407.71

# %% [markdown]
# #Decision Tree Regressor

# %%
from pyspark.ml.regression import DecisionTreeRegressor

dt = DecisionTreeRegressor(featuresCol = 'features', labelCol='week_day_end_price')
dt_model = dt.fit(train)

# %%
from  pyspark.sql.functions import abs

predictions_dt = dt_model.transform(test)
x_dt =((predictions_dt['week_day_end_price']-predictions_dt['prediction'])/predictions_dt['week_day_end_price'])*100
predictions_dt = predictions_dt.withColumn('Accuracy',abs(x_dt))
predictions_dt.select("prediction","week_day_end_price","Accuracy","features").show()
# Out:
# +------------------+------------------+------------------+--------------------+
# |        prediction|week_day_end_price|          Accuracy|            features|
# +------------------+------------------+------------------+--------------------+
# | 3906.534423828125|         4980.6704|21.566092470961713|[3908.23681640625...|
# | 9297.384114583334|         10724.805|13.309525110330044|[7896.830078125,3...|
# |         14816.625|         18318.875|19.118259172574735|[16200.0927734375...|
# |   4395.6240234375|         3908.2368|12.470769554835172|[3906.53442382812...|
# |     6365.11328125|         3508.6577| 81.41163369460949|[6365.11328125,2....|
# | 6579.897705078125|         6665.8735|1.2897908972422427|[6658.83154296875...|
# |   4395.6240234375|         3700.6787|18.778861035573343|[3773.259765625,8...|
# | 9297.384114583334|          8358.547|11.232062864794713|[8257.533203125,3...|
# | 9297.384114583334|         7880.5845|17.978357402842914|[8358.546875,3.10...|
# |10343.394897460938|          8257.533| 25.26010665687132|[10174.287109375,...|
# | 6579.897705078125|         8157.1206|19.335534886332475|[6960.03173828125...|
# +------------------+------------------+------------------+--------------------+

# %%
from pyspark.ml.evaluation import RegressionEvaluator

evaluator_dt = RegressionEvaluator(
    labelCol="week_day_end_price", predictionCol="prediction", metricName="rmse")
rmse_dt = evaluator_dt.evaluate(predictions_dt)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse_dt)
# Out:
# Root Mean Squared Error (RMSE) on test data = 1759.94
